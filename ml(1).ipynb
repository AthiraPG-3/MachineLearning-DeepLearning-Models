# %% [markdown]
# <a href="https://colab.research.google.com/github/AthiraPG-3/MachineLearning-DeepLearning-Models/blob/main/ml(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
eta = 0.1
n_iterations = 1000
m1=100
theta = np.random.randn(2,1)
X = 2 * np.random.rand(100,1)
y = 4 + 3 * X + np.random.randn(100,1)
print(X.shape)
# Out:
# (100, 1)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X,y)
c = lin_reg.intercept_
m = lin_reg.coef_
print(m,c)
# Out:
# [[3.012252]] [3.94205394]

# %%
X_new = np.array([[0],[2]])
y_new = lin_reg.predict(X_new)
print(y_new)
# Out:
# [[3.94205394]
#  [9.96655794]]

# %%
import matplotlib.pyplot as plt
plt.plot(X_new,y_new, "r-")
plt.plot(X,y,"b.")
plt.axis([0,2,0,15])
plt.show()

# %%
X_b = np.c_[np.ones((100,1)),X] #add x0=1 to each instance
theta_best=np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
print(theta_best)
# Out:
# [[4.0611186 ]
#  [2.91816236]]

# %%
y2= 2.89644755*2+4.06724679
print(y2)
# Out:
# 9.86014189
